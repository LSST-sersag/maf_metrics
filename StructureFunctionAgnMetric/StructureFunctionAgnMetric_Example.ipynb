# %%
from StructureFunctionAgnMetric import *
# %matplotlib inline
path = '/home/idies/workspace/lsst_cadence/FBS_1.5/agnddf_v1.5_10yrs.db'
test = StructureFunctionAgnMetric(path)


test.plot_heatmap()
# Out:
# You need to run StructureFunctionAgnMetric in order to obtain desired plots

# %%
test.runAll()
# Out:
# Querying database SummaryAllProps with constraint filter = 'r' for columns ['observationStartMJD', 'fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth']
# Found 469008 visits
# Running:  [0]
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.

# %%
test.setNlc(10)
test.plot_heatmap()
# Out:
# You need to run StructureFunctionAgnMetric in order to obtain desired plots

# %%
test.runAll()
# Out:
# Querying database SummaryAllProps with constraint filter = 'r' for columns ['observationStartMJD', 'fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth']
# Found 469008 visits
# Running:  [0]
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
